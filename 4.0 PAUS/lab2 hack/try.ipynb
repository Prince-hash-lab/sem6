# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv("h1-test_data.csv")
d2=pd.read_csv("h1-train_data.csv")

# %%
d1.head()
# Out:
#                  id       f1       f2       f3       f4       f5       f6  \
# 0  nc3dea071da1944b  0.24847  0.55312  0.70589  0.71547  0.44433  0.34094
# 1  n22d95133dce7449  0.35610  0.50317  0.56731  0.58409  0.34255  0.38761
# 2  ndb9c52980cd9476  0.26545  0.63635  0.62526  0.36129  0.47972  0.43528
# 3  na13ca2a8d090425  0.41565  0.40977  0.59554  0.51657  0.41246  0.36535
# 4  nb9b008749ee643a  0.30859  0.53767  0.37151  0.25692  0.23348  0.45774
#
#         f7       f8       f9  ...      f41      f42      f43      f44  \
# 0  0.39226  0.48390  0.44880  ...  0.47379  0.66464  0.23107  0.32082
# 1  0.55026  0.59748  0.49126  ...  0.64071  0.51043  0.53355  0.46335
# 2  0.53891  0.68595  0.46213  ...  0.64222  0.59059  0.28314  0.24980
# 3  0.48067  0.62167  0.56247  ...  0.51400  0.47849  0.39664  0.33040
# 4  0.45095  0.40326  0.49709  ...  0.78476  0.35612  0.65674  0.66758
#
#        f45      f46      f47      f48      f49      f50
# ...

# %%
d2.head()
# Out:
#                  id       f1       f2       f3       f4       f5       f6  \
# 0  n0d752bda055a4b2  0.52843  0.66492  0.57300  0.25224  0.39213  0.56593
# 1  n78c526e96e3444a  0.50478  0.53147  0.46412  0.38045  0.52160  0.50398
# 2  n124153d6a80b41e  0.16432  0.30201  0.43268  0.76786  0.58864  0.24046
# 3  n8d840c1eca9947c  0.39355  0.33501  0.76737  0.57453  0.58991  0.49938
# 4  n9085bca7d6274e8  0.30337  0.62905  0.70896  0.35969  0.45878  0.56114
#
#         f7       f8       f9  ...      f42      f43      f44      f45  \
# 0  0.27157  0.67453  0.55690  ...  0.21561  0.65484  0.47571  0.42559
# 1  0.60157  0.44022  0.48668  ...  0.65698  0.62031  0.59613  0.45587
# 2  0.46519  0.63948  0.50190  ...  0.48324  0.37271  0.19784  0.42810
# 3  0.42713  0.71836  0.47394  ...  0.54231  0.16994  0.31166  0.66766
# 4  0.45075  0.61684  0.58865  ...  0.52879  0.40566  0.35881  0.59963
#
#        f46      f47      f48      f49      f50  target
# ...

# %%
import seaborn as sns

# %%
import missingno as msno
msno.matrix(d2)
# Out:
# <AxesSubplot:>

# %%
x_train = d2.iloc[:, 0:51]
y_train = d2['target']
x_test = d1.iloc[:, 0:51]

# %%
x_train.head()
x_test.head()
# Out:
#                  id       f1       f2       f3       f4       f5       f6  \
# 0  nc3dea071da1944b  0.24847  0.55312  0.70589  0.71547  0.44433  0.34094
# 1  n22d95133dce7449  0.35610  0.50317  0.56731  0.58409  0.34255  0.38761
# 2  ndb9c52980cd9476  0.26545  0.63635  0.62526  0.36129  0.47972  0.43528
# 3  na13ca2a8d090425  0.41565  0.40977  0.59554  0.51657  0.41246  0.36535
# 4  nb9b008749ee643a  0.30859  0.53767  0.37151  0.25692  0.23348  0.45774
#
#         f7       f8       f9  ...      f41      f42      f43      f44  \
# 0  0.39226  0.48390  0.44880  ...  0.47379  0.66464  0.23107  0.32082
# 1  0.55026  0.59748  0.49126  ...  0.64071  0.51043  0.53355  0.46335
# 2  0.53891  0.68595  0.46213  ...  0.64222  0.59059  0.28314  0.24980
# 3  0.48067  0.62167  0.56247  ...  0.51400  0.47849  0.39664  0.33040
# 4  0.45095  0.40326  0.49709  ...  0.78476  0.35612  0.65674  0.66758
#
#        f45      f46      f47      f48      f49      f50
# ...

# %%
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
setup(data=df, target='target', session_id = 165, train_size = 0.9, imputation_type = 'iterative', 
      polynomial_features = True, polynomial_degree = 10,
      # feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.5,
      remove_outliers = True, outliers_threshold = 0.05, 
      # pca = True, pca_method = 'incremental',
      normalize = True, normalize_method = 'zscore',
      transformation = True, transformation_method = 'quantile', 
      silent=True)
qdaModel = create_model('qda')


predict_data = pd.read_csv("/content/h1-test_data.csv")
predict = predict_data.iloc[:, 1:]

newPredictions = predict_model(qdaModel, data = predict)
newPredictions


final_df = pd.DataFrame(columns = ["id", "target"])
final_df["id"] = predict_data["id"]
final_df["target"] = list(newPredictions['Label'])
final_df.to_csv("Submission 1 duplicate.csv", index = False)
# Out:
# ---------------------------------------------------------------------
# NameError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12648/2480699195.py in <module>
# ----> 1 setup(data=df, target='target', session_id = 165, train_size = 0.9, imputation_type = 'iterative',
#       2       polynomial_features = True, polynomial_degree = 10,
#       3       # feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.5,
#       4       remove_outliers = True, outliers_threshold = 0.05,
#       5       # pca = True, pca_method = 'incremental',
#
# NameError: name 'setup' is not defined
