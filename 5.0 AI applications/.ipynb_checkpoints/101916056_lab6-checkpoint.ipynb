# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript
# louis    intro\nfade the music out. lets roll. hold the...
# dave     this is dave. he tells dirty jokes for a livin...
# ricky    hello. hello! how you doing? great. thank you....
# bo           ©  scraps from the loft. all rights reserved.
# bill     [cheers and applause] all right, thank you! th...
# jim      [car horn honks] [audience cheering] [announce...
# john     armed with boyish charm and a sharp wit, the f...
# hasan        ©  scraps from the loft. all rights reserved.
# ali      ladies and gentlemen, please welcome to the st...
# anthony  thank you. thank you. thank you, san francisco...
# mike     wow. hey, thank you. thanks. thank you, guys. ...
# joe      [rock music playing] [audience cheering] [anno...

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'ladies and gentlemen, please welcome to the stage: ali wong! hi. hello! welcome! thank you! thank you for coming. hello! hello. we are gonna have to get this shit over with, cause i have to pee in, li'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'ladies': ['and', 'who', 'and', 'who'],
#  'and': ['gentlemen,',
#   'foremost,',
#   'then',
#   'have',
#   'theres',
#   'resentment',
#   'get',
#   'get',
#   'says,',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'everybody',
#   'my',
#   'she',
#   'i',
#   'im',
#   'i',
#   'i',
#   'the',
#   'i',
#   'i',
#   'has',
#   'i',
#   'we',
#   'we–',
#   'then',
#   'i',
#   'watched',
#   'i',
#   'have',
#   'that',
#   'you',
#   'recycling,',
#   'disturbing',
#   'its',
#   'all',
#   'just',
#   'then',
#   'be',
#   'half-vietnamese.',
#   'we',
#   'his',
#   'i',
#   'slide.',
#   'your',
#   'inflamed',
#   'youre',
#   'then',
#   'i',
#   'half-japanese',
#   'im',
#   'half-vietnamese.',
#   'half-jungle',
#   'playing',
#   'rugby.',
#   'on',
#   'foremost,',
#   'a',
#   'the',
#   'emotionally',
#   'i',
#   '',
#   'so,',
#   'neither',
#   'i',
#   'i–',
#   'then',
#   'its',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'then',
#   'look,',
#   'very',
#   'for',
#   'i',
#   'she',
#   'rise',
#   'her',
#   'be',
#   'eat',
#   'watch',
#   'then,',
#   'be',
#   'now',
#   'theyre',
#   'most',
#   'theyll',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'you',
#   'youre',
#   'then',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say,',
#   'my',
#   'he',
#   'when',
#   'im',
#   'just',
#   'i',
#   'what',
#   'sicker,',
#   'sicker.',
#   'sicker,',
#   'sicker,',
#   'posted',
#   'all',
#   'theyre',
#   'thats',
#   'lies.',
#   'as',
#   'treat',
#   'youll',
#   'succeed,',
#   'they',
#   'i',
#   'you',
#   'its',
#   'then,',
#   'thats',
#   'be',
#   'im',
#   'i',
#   'just',
#   'sisters.',
#   'a',
#   'unusual',
#   'theyll',
#   'boring.',
#   'all',
#   'their',
#   'wearing',
#   'famous',
#   'they',
#   'youre',
#   'just',
#   'therefore,',
#   'you',
#   'ignore',
#   'then,',
#   'she',
#   'when',
#   'the',
#   'biggie',
#   'it–',
#   'it',
#   'my',
#   'your',
#   'there',
#   'i',
#   'a',
#   'i',
#   'push',
#   'then,',
#   'then,',
#   'melt',
#   'i',
#   'then,',
#   'then',
#   'sniff',
#   'i',
#   'youve',
#   'i',
#   'outside',
#   'as',
#   'rapey',
#   'they',
#   'most',
#   'see',
#   'id',
#   'i',
#   'he',
#   'instead',
#   'then,',
#   'then,',
#   'remember',
#   'then,',
#   'hold',
#   'i',
#   'do',
#   'then',
#   'to',
#   'a',
#   'a',
#   'terrible.',
#   'i',
#   'when',
#   'everything',
#   'the',
#   'i',
#   'then',
#   'i',
#   'most',
#   'i',
#   'he',
#   'i',
#   'held',
#   'got',
#   'i',
#   'your',
#   'just',
#   'he',
#   'i',
#   'it',
#   'leaves',
#   'dark.',
#   'then,',
#   'naked,',
#   'a',
#   'i',
#   'i',
#   'my',
#   'then,',
#   'then',
#   'recently',
#   'me,',
#   'now,',
#   'a',
#   'is',
#   'insecurities',
#   'his',
#   'comedy'],
#  'gentlemen,': ['please'],
#  'please': ['welcome', 'look'],
#  'welcome': ['to'],
#  'to': ['the',
#   'get',
#   'pee',
#   'sleep,',
#   'sleep.',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'deepak-oprah,',
#   'achieve',
#   'a',
#   'trap',
#   'it',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women.',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work.',
#   'earn',
#   'shit',
#   'seat.',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'make',
#   'just',
#   'the',
#   'podcasts.',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'you.\ni',
#   'put',
#   'do',
#   'help',
#   'now,',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do.',
#   'her,',
#   'use',
#   'say,',
#   'get',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me.',
#   'me',
#   'live',
#   'die.',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go.',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be.',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish,',
#   'finish.',
#   'come',
#   'make',
#   'be',
#   'be',
#   'be',
#   'me,',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'keyser',
#   'freak',
#   'freak',
#   'it.',
#   'cleanse.',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me.',
#   'harvard'],
#  'the': ['stage:',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'life-changing',
#   'center',
#   'hoarding',
#   'hpv',
#   'country',
#   'third',
#   'communists.\nthe',
#   'worst',
#   'manual.',
#   'calculator',
#   'future.',
#   'tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside,',
#   'inside.',
#   'first',
#   'time,',
#   'fifth',
#   'next',
#   'back',
#   'park.',
#   'middle',
#   'money',
#   'colonizer!',
#   'advantage',
#   'time.',
#   'sexiest.',
#   'sexiest.',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference.',
#   'fancy',
#   'chinese,',
#   'japanese.',
#   'east',
#   'west',
#   'name,',
#   'bathroom.',
#   'bathroom',
#   'corner.',
#   'wait',
#   'wall',
#   'fuck',
#   'house.',
#   'idea',
#   'mans',
#   'message,',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'c.o.o.',
#   'table',
#   'top.',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret.',
#   'phrase,',
#   'street.',
#   'boat',
#   'best',
#   'desert.',
#   'stall.',
#   'end',
#   'day',
#   'goonies.',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet.',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'images',
#   'internet',
#   'back.',
#   'internet',
#   'jewish',
#   'universe',
#   'pain.',
#   'pain.',
#   'pain.',
#   'dick.',
#   'butt,',
#   'tush-tush.',
#   'man',
#   'look',
#   'mans',
#   'first',
#   'woman,',
#   'lord',
#   'rim,',
#   'most',
#   'most',
#   'woman',
#   'time,',
#   'boss.',
#   'boss',
#   'time,',
#   'bedroom,',
#   'boss.',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'babys',
#   'dream.',
#   'point.',
#   'ultimate',
#   'world',
#   'rest',
#   'galapagos,',
#   'phrase',
#   'women,',
#   'side',
#   'hood,',
#   'movie,',
#   'park,',
#   'sun.',
#   'sun',
#   'tupac',
#   'time?',
#   'time,',
#   'peace',
#   'boat,',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood.',
#   'eggs',
#   'month,',
#   "kraken!'",
#   'time,',
#   'smiley',
#   'ovulation',
#   'time,',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'lord',
#   'size',
#   'twins',
#   'toilet,',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table?',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house.',
#   'dishes?',
#   'plants?',
#   'channel.',
#   'star',
#   'show.',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same.',
#   'escrow',
#   'one',
#   'epicenter',
#   'stage',
#   'loft.'],
#  'stage:': ['ali'],
#  'ali': ['wong!', 'wong.'],
#  'wong!': ['hi.'],
#  'hi.': ['hello!'],
#  'hello!': ['welcome!', 'hello.'],
#  'welcome!': ['thank'],
#  'thank': ['you!', 'you', 'you,', 'you,', 'you.'],
#  'you!': ['thank', 'cause'],
#  'you': ['for',
#   'dont',
#   'go',
#   'go',
#   'dont',
#   'can',
#   'never',
#   'better',
#   'under',
#   'never',
#   'might',
#   'die.',
#   'wanna',
#   'wanna',
#   'gotta',
#   'homeless',
#   'a',
#   'drop',
#   'know,',
#   'go',
#   'know,',
#   'feel',
#   'feel',
#   'know.',
#   'feel',
#   'know,',
#   'about',
#   'to',
#   'know,',
#   'know,',
#   'right',
#   'know?\nbut',
#   'get',
#   'get',
#   'like!',
#   'dont',
#   'know?\nmy',
#   'guys',
#   'know?',
#   'mess',
#   'guys',
#   'know,',
#   'can',
#   'can',
#   'eat',
#   'queef',
#   'know,',
#   'gotta',
#   'know',
#   'marry',
#   'something.',
#   'would',
#   'dont',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry,',
#   'never',
#   'dare',
#   'know,',
#   'deep,',
#   'need',
#   'need',
#   'not',
#   'guys',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'tell',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know',
#   'aint',
#   'now.',
#   'have',
#   'gotta',
#   'gotta',
#   'dont',
#   'gotta',
#   'put',
#   'know?',
#   'havent',
#   'only',
#   'know,',
#   'stick',
#   'know?',
#   'just',
#   'as',
#   'know?',
#   'ok?',
#   'all',
#   'know',
#   'respect',
#   'need',
#   'know?',
#   'know?',
#   'what',
#   'be',
#   'so,',
#   'have',
#   'know?',
#   'know',
#   'know',
#   'guys',
#   'know,',
#   'gonna',
#   'just',
#   'know?\nanother',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know?',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'could',
#   'scratch',
#   'can',
#   'urgently',
#   'gotta',
#   'need',
#   'guys',
#   'do',
#   'pee',
#   'when',
#   'when',
#   'to',
#   'know?',
#   'that–',
#   'look.',
#   'watch',
#   'know',
#   'know',
#   'know',
#   'push,',
#   'push,',
#   'push,',
#   'just',
#   'think',
#   'wash',
#   'water',
#   'makin',
#   'change',
#   'know,',
#   'about',
#   'get',
#   'know?',
#   'know,',
#   'owe',
#   'see',
#   'know?',
#   'know,',
#   'think'],
#  'for': ['coming.',
#   'coming.',
#   'me.',
#   'me.',
#   'me',
#   'my',
#   'fashion',
#   'warmth?',
#   'marriage,',
#   'them.',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us,',
#   'fresh',
#   'me',
#   'them.',
#   'his',
#   'the',
#   'once.',
#   'the',
#   'all',
#   'the',
#   'me',
#   'me,',
#   'me',
#   'a',
#   'them.',
#   'granted',
#   'a',
#   'a',
#   'me.',
#   'a',
#   '',
#   '',
#   'coming',
#   'the',
#   'playing',
#   'being',
#   'doing'],
#  'coming.': ['hello!', 'um', 'you'],
#  'hello.': ['we'],
#  'we': ['are',
#   'were',
#   'were',
#   'were',
#   'had,',
#   'had',
#   'had',
#   'were',
#   'were',
#   'spend',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'pay',
#   'do',
#   'eat',
#   'eat',
#   'eat',
#   'do',
#   'are',
#   'have',
#   'got',
#   'as',
#   'had',
#   'could',
#   'dont',
#   'better',
#   'could',
#   'could',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'all',
#   'dont',
#   'live',
#   'wouldnt',
#   'got',
#   'got',
#   'bought',
#   'die.'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'you',
#   'c.e.o.s,',
#   'never',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin.',
#   'in',
#   'you',
#   'marked'],
#  'gonna': ['have',
#   'turn',
#   'die',
#   'overtake',
#   'have',
#   'trap',
#   'propose',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live.',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear,',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be.',
#   'recycle',
#   'burn',
#   'be.',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'hpv',
#   'it',
#   'hpv',
#   'hpv,',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to,',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex,',
#   'to',
#   'had',
#   'to',
#   'the',
#   'a'],
#  'get': ['this',
#   'it.',
#   'it.',
#   'rid',
#   'it,',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker,',
#   'sicker,',
#   'really,',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant.',
#   'pregnant,',
#   'up',
#   'into',
#   'older.',
#   'as',
#   'a',
#   'pregnant.',
#   'pregnant',
#   'that',
#   'my',
#   'pregnant,',
#   'huge',
#   'dark',
#   'big–',
#   'big,',
#   'all',
#   'pregnant.'],
#  'this': ['shit',
#   'year.',
#   'doctor,',
#   'shit',
#   'shit',
#   'calculator',
#   'judy',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'is',
#   'restaurant',
#   'restaurant',
#   'hippy-dippy',
#   'sneaking',
#   'wacky',
#   'dude,',
#   'dude,',
#   'bitch',
#   'huge',
#   'shit?',
#   'conversation.',
#   'is',
#   'fucking',
#   'relatable',
#   'is',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit.',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   'and',
#   'around?',
#   'around?',
#   'up',
#   'is',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'was',
#   'together',
#   'together.',
#   'turns',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore.',
#   'that'],
#  'over': ['with,', 'again.', 'again.', 'by', 'his'],
#  'with,': ['cause'],
#  'cause': ['i',
#   'im',
#   'it',
#   'it',
#   'he',
#   'i',
#   'were',
#   'my',
#   'youre',
#   'when',
#   'its',
#   'if',
#   'her',
#   'she',
#   'its',
#   'you',
#   'i',
#   'i'],
#  'i': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'dont',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am,',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'grew',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew,',
#   'was',
#   'dropped',
#   'was',
#   'just',
#   'dont',
#   'get',
#   'mean,',
#   'just',
#   'could',
#   'could',
#   'think',
#   'was',
#   'dont',
#   'did',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee,',
#   'need',
#   'grew',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted.',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'was.',
#   'did',
#   'dont',
#   'dont.',
#   'straight',
#   'dont',
#   'do',
#   'dont',
#   'dont',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'saw',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said,',
#   'do,',
#   'really',
#   'dont',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'dont',
#   'just',
#   'gotta',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was,',
#   'got',
#   'just',
#   'dont–',
#   'dont!',
#   'dont!',
#   'like',
#   'respect',
#   'know',
#   'dont',
#   'dont',
#   'also',
#   'just',
#   'cant',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want?',
#   'wanna',
#   'have',
#   'dont',
#   'am',
#   'dare',
#   'just',
#   'identify.',
#   'dont',
#   'was',
#   'won,',
#   'was',
#   'really',
#   'changed',
#   'changed',
#   'get',
#   'need',
#   'dont',
#   'need',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'also',
#   'know,',
#   'slime',
#   'slime',
#   'dont',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'dont',
#   'had',
#   'cant',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'dont',
#   'was',
#   'lost.',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'cant',
#   'can',
#   'am',
#   'am',
#   'didnt',
#   'can',
#   'cant',
#   'get',
#   'do',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didnt',
#   'didnt',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'dont'],
#  'pee': ['in,', 'on'],
#  'in,': ['like,', 'ok?', 'has'],
#  'like,': ['ten',
#   'you',
#   'but',
#   'oh,',
#   'oh,',
#   'all',
#   'we',
#   'hey,',
#   'wassup?',
#   'hey,',
#   'where?',
#   'at',
#   'oh,',
#   'you',
#   'i',
#   'hold',
#   'i',
#   'its',
#   'its',
#   'private',
#   'we',
#   'oh,',
#   'im',
#   'shut',
#   'oh,',
#   'you',
#   'very',
#   'were',
#   'we',
#   'but,',
#   'look',
#   'that',
#   'oh,',
#   'you',
#   'hey,',
#   'why',
#   'uh,',
#   'oh,',
#   'oh,',
#   'yes,',
#   'i',
#   'become',
#   'a',
#   'guys,',
#   'thats',
#   'ali,',
#   'yeah,',
#   'why',
#   'yeah,',
#   'yeah!',
#   'oh,',
#   'im',
#   'im',
#   'oh,',
#   'only',
#   'were',
#   'release',
#   'we',
#   'ok,',
#   'hey,',
#   'oh,',
#   'uh,',
#   'no!',
#   'yes!',
#   'you',
#   'yeah,',
#   'that',
#   'this',
#   'i',
#   'a',
#   'a',
#   'you,',
#   'really',
#   'why',
#   'way'],
#  'ten': ['minutes.', 'gallons', 'times'],
#  'minutes.': ['but'],
#  'but': ['thank',
#   'fuck',
#   'i',
#   'my',
#   'i',
#   'he',
#   'sometimes,',
#   'i',
#   'its',
#   'dont',
#   'i',
#   'i',
#   'im',
#   'my',
#   'what',
#   'hes',
#   'mostly',
#   'im',
#   'its'],
#  'you,': ['everybody,',
#   'five',
#   'but',
#   'right?',
#   'i',
#   'cause',
#   'boom,',
#   'you.'],
#  'everybody,': ['so'],
#  'so': ['much',
#   'emotional.',
#   'emotional',
#   'i',
#   'much',
#   'vulnerable',
#   'smooth,',
#   'that',
#   'good.',
#   'many',
#   'that',
#   'that',
#   'in',
#   'that',
#   'do',
#   'annoying',
#   'that',
#   'embarrassing.',
#   'lonely.',
#   'juicy.',
#   'hot.',
#   'that,',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'much',
#   'little',
#   'little',
#   'supportive.',
#   'that',
#   'that',
#   'that'],
#  'much': ['for', 'better', 'chemistry.', 'shittier', 'netflix', 'resentment,'],
#  'um': ['its', 'yeah,'],
#  'its': ['a',
#   'been',
#   'like',
#   'ok.',
#   'coming.',
#   'undetectable',
#   'really',
#   'a',
#   'too',
#   'very,',
#   'hot',
#   'amazing.',
#   'what',
#   'like',
#   'so',
#   'all',
#   'its',
#   'different.',
#   'authentic',
#   'not',
#   'funny,',
#   'too',
#   'a',
#   'a',
#   'probably',
#   'basically',
#   'been',
#   'very',
#   'because',
#   'ok,',
#   'like',
#   'like',
#   'the',
#   'because',
#   'sexist',
#   'very',
#   'so',
#   'a',
#   'a',
#   'what',
#   'lonely.',
#   'a',
#   'very',
#   'all',
#   'too',
#   'easter',
#   'like,',
#   'go',
#   'not',
#   'because',
#   'when',
#   'super',
#   'whatevs,',
#   'toll',
#   'different.',
#   'not',
#   'straight',
#   'neosporin.'],
#  'a': ['very',
#   'very',
#   'shit',
#   'six-pack,',
#   'ambien',
#   'meditation',
#   'fucking',
#   'lot',
#   'ghost',
#   'self-help',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictators',
#   'shovel',
#   'climax',
#   'texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'lot',
#   'grown-ass',
#   'mattress',
#   'kitchen.',
#   'very',
#   'catch.',
#   'secret',
#   'public',
#   'hipster?',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'yoko',
#   'white',
#   'white',
#   'wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin.',
#   'slip',
#   'jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend.',
#   'thousand',
#   'shitty',
#   'woman',
#   'new',
#   'man',
#   'pinterest',
#   'saturday.',
#   'completely',
#   'lot',
#   'lot',
#   'genius.',
#   'housewife,',
#   'great',
#   'lot.',
#   'great',
#   'office',
#   'office',
#   'office.',
#   'day,',
#   'sad-ass',
#   'macgyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'disgusting',
#   'pervert.',
#   'gross',
#   'very',
#   'young',
#   'idiot,',
#   'lot',
#   'result,',
#   'little',
#   'second',
#   'whole',
#   'big',
#   'conqueror.',
#   'little–',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife,',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk,',
#   'quarter,',
#   'princess.',
#   'vietnam',
#   'half',
#   'female',
#   'baby,',
#   'week',
#   'little',
#   'sudden.',
#   'frozen',
#   'lot',
#   'lot',
#   'kid.',
#   'kid?',
#   'lot',
#   'kid,',
#   'kid?',
#   'asian',
#   'billion.',
#   'turtle',
#   'right',
#   'u-turn!',
#   'o-turn!',
#   'car',
#   'mess.',
#   'full',
#   'century',
#   'living.',
#   'fuck.',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smokers',
#   'side',
#   'sandwich.',
#   'way',
#   'doctor.',
#   'kid,',
#   'lot',
#   'lot',
#   'while,',
#   'bunch',
#   'dictatorship,',
#   'hand',
#   'man',
#   'zombie,',
#   'half',
#   'miscarriage,',
#   'lot',
#   'miscarriage.',
#   'third',
#   'pair',
#   'reason.',
#   'heartbeat.',
#   'miscarriage.',
#   'month',
#   'bike',
#   'doula.',
#   'doula',
#   'white',
#   'lot',
#   'soft',
#   'baby',
#   'child',
#   'marriage,',
#   'eyeball,',
#   'foot?',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye.',
#   'minion.',
#   'year,',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good'],
#  'very': ['exciting',
#   'exciting',
#   'helpful,',
#   'lucky',
#   'unusual',
#   'confusing',
#   'you',
#   'picturesque',
#   'underrated.',
#   'well',
#   'surprised',
#   'soft,',
#   'nurturing',
#   'domestic.',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing,',
#   'clinical.',
#   'universal',
#   'grateful',
#   'common.',
#   'early.',
#   'much.',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'and',
#   'was',
#   'jobs,',
#   'like',
#   'long.',
#   'looks',
#   'since.',
#   'long.',
#   'on'],
#  'me.': ['its',
#   'i',
#   'and',
#   'cause',
#   'and',
#   'when–',
#   'ok?',
#   'you',
#   'because',
#   'like,',
#   'thats',
#   'and',
#   'oh,',
#   'i',
#   'oh,',
#   'how'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'ali'],
#  'year': ['for', 'i'],
#  'turned': [''],
#  '': ['this',
#   'is',
#   'probably',
#   'percent',
#   'percent',
#   'imports.',
#   'and',
#   'years',
#   'flip',
#   'days.',
#   'days,',
#   'years',
#   '\n\n',
#   'scraps'],
#  'year.': ['yes!', 'uh,'],
#  'yes!': ['thank', 'the'],
#  'five': ['people.', 'years,', 'years,'],
#  'people.': ['i', 'its', 'like,', 'i', 'thats'],
#  'appreciate': ['that.'],
#  'that.': ['uh,', 'uh,', 'they', 'dont', 'im', 'theyre', 'im', 'i'],
#  'uh,': ['i',
#   'this',
#   'hes–',
#   'between',
#   'you',
#   'we',
#   'youre',
#   'im',
#   'mmm.',
#   'yeah.',
#   'two'],
#  'can': ['tell',
#   'also',
#   'i',
#   'i',
#   'never',
#   'you',
#   'be',
#   'tell,',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk,',
#   'comfortably',
#   'tell,',
#   'just',
#   'think',
#   'i',
#   'i',
#   'i',
#   'already',
#   'really',
#   'you',
#   'you',
#   'already',
#   'see,',
#   'find'],
#  'tell': ['that',
#   'that',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'you',
#   'because',
#   'you'],
#  'that': ['im',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'i',
#   'im',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'im',
#   'will',
#   'he',
#   'your',
#   'has',
#   'store',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement',
#   'for',
#   'you',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'seems',
#   'he',
#   'youre',
#   'i',
#   'i',
#   'so',
#   'hed',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'well',
#   'fucking',
#   'housewife,',
#   'bitch',
#   'horrible',
#   'one-ply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'i',
#   'y-you',
#   'if',
#   'hes',
#   'and',
#   'you',
#   'if',
#   'then,',
#   'theyre',
#   'fear.',
#   'shit',
#   'fear',
#   'he',
#   'we',
#   'im',
#   'i',
#   'woman',
#   'now,',
#   'whole',
#   '$-a-box',
#   'was',
#   'was',
#   'babys',
#   'everybody',
#   'its',
#   'came',
#   'shes',
#   'cause',
#   'to',
#   'you',
#   'snail-trail',
#   'is',
#   'my',
#   'were',
#   'it',
#   'its',
#   'tell',
#   'means,',
#   'they',
#   'they',
#   'day',
#   'says,',
#   'that',
#   'stupid-ass',
#   'i',
#   'harvard',
#   'i',
#   'shit',
#   'is?',
#   'blows',
#   'youre',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'hes',
#   'goes',
#   'they',
#   'the',
#   'the',
#   'im',
#   'my'],
#  'im': ['getting',
#   'straight',
#   'jealous,',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'half-chinese',
#   'half-chinese',
#   'just',
#   'a',
#   'very',
#   'like,',
#   "done.'",
#   'done.',
#   'not',
#   'a–',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'just',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed,',
#   'gonna',
#   'like,',
#   'still',
#   'just',
#   'older,',
#   'not',
#   'just',
#   'only',
#   'only',
#   'gonna',
#   ',',
#   'very',
#   '.',
#   'from,',
#   'scared',
#   'very,',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked.',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older,', 'older,', 'busy', 'massages'],
#  'older,': ['because,', 'because', 'when'],
#  'because,': ['now,', 'usually,', 'when', 'last'],
#  'now,': ['when', 'if', 'because', 'instead', 'and', 'if'],
#  'when': ['i',
#   'they',
#   'a',
#   'youre',
#   'she',
#   'we',
#   'you',
#   'you',
#   'i',
#   'youre',
#   'a',
#   'i',
#   'you',
#   'i',
#   'our',
#   'you',
#   'we',
#   'i',
#   'i',
#   'i',
#   'i',
#   'you',
#   'he',
#   'i',
#   'that',
#   'ive',
#   'you',
#   'youre',
#   'they',
#   'i',
#   'im',
#   'i',
#   'i',
#   'my',
#   'you',
#   'trying',
#   'i',
#   'everything',
#   'i',
#   'can',
#   'can',
#   'can',
#   'my',
#   'in–',
#   'youre',
#   'the',
#   'its',
#   'it',
#   'they',
#   'i',
#   'somebody',
#   'somebody',
#   'he',
#   'a',
#   'they',
#   'they',
#   'youre',
#   'they',
#   'i',
#   'i',
#   'theyre',
#   'youre',
#   'you',
#   'he',
#   'you',
#   'i',
#   'it',
#   'its',
#   'its'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'whos',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'beyoncé.',
#   'how',
#   'how',
#   'if',
#   'me'],
#  'an': ['-year-old', 'atm', 'impression', 'investment', 'unconventional'],
#  '-year-old': ['girl,', 'girls,'],
#  'girl,': ['my', 'because', 'when'],
#  'my': ['automatic',
#   'doctor',
#   'body',
#   'kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life.',
#   'generation.',
#   'time.',
#   'mom',
#   'optimum',
#   'husband,',
#   'league,',
#   'god,',
#   'god,',
#   'part.',
#   'generation.',
#   'volvo.',
#   'husband',
#   'pussy.',
#   'god.',
#   'husband,',
#   'god.',
#   'bed',
#   'husband',
#   'god!',
#   'pinterest',
#   'best',
#   'wedding',
#   'husband,',
#   'personality',
#   'heart.',
#   'financial',
#   'friends,',
#   'co-workers.',
#   'toilet',
#   'fingers',
#   'co-workers',
#   'co-workers',
#   'shit',
#   'father-in-law',
#   'husband',
#   'life?',
#   'destiny.',
#   'last',
#   'mom,',
#   'dad,',
#   'grandma.',
#   ',',
#   'god!',
#   'god!',
#   'husband',
#   'husband',
#   'asian-american',
#   'female',
#   'friends',
#   'husband',
#   'mind,',
#   'mind',
#   'god,',
#   'face',
#   'toyota',
#   'mom',
#   'husband',
#   'destiny,',
#   'body',
#   'pussy',
#   'god,',
#   'fault.',
#   ',',
#   'uterus',
#   'progesterone',
#   'writing',
#   'co-workers,',
#   'underwear,',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers?',
#   'fingers?',
#   'fingers?',
#   'husband',
#   'god,',
#   'husband',
#   'face',
#   'god.',
#   'mom–',
#   'six-week',
#   'god,',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband.',
#   'husband',
#   'doctors',
#   'god.',
#   'blood',
#   'husband',
#   'nipples',
#   'pussys',
#   'pussys',
#   'bodys',
#   'husband,',
#   'league,',
#   'god,',
#   'dreams',
#   'beautiful,',
#   'hard-earned',
#   'ass.'],
#  'automatic': ['thought'],
#  'thought': ['is', 'it', 'they', 'it'],
#  'is': ['fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'that?',
#   'a',
#   'a',
#   'that',
#   'asian.',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like,',
#   'always,',
#   'called',
#   'the',
#   'a',
#   'its',
#   'to',
#   'that',
#   'doo',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   ',',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious!',
#   'so',
#   'it',
#   'taking',
#   'holding'],
#  'fuck': ['you.',
#   'you.',
#   'you!',
#   'they',
#   'up!',
#   'down.',
#   'one',
#   'him',
#   'up.',
#   'i'],
#  'you.': ['fuck',
#   'i',
#   'a',
#   'dont',
#   'theres–',
#   'ghostbusters!',
#   'you',
#   'my',
#   'your'],
#  'dont': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'ever',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'tell',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'try',
#   'your',
#   'wanna',
#   'wanna',
#   'worry,',
#   'cheat',
#   'wanna',
#   'kill',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack.',
#   'die.',
#   'die.',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'feel',
#   'tell',
#   'work,'],
#  'even': ['know', 'know', 'accidentally', 'effective.', 'have', 'come'],
#  'know': ['you,',
#   'what',
#   'that',
#   'when',
#   'where',
#   'what',
#   'when',
#   'that',
#   'whats',
#   'why',
#   'the',
#   'anything',
#   'what',
#   'that',
#   'how',
#   'how',
#   'you',
#   'that',
#   'freaked',
#   'i',
#   'you',
#   'what',
#   'youve',
#   'what',
#   'if',
#   'whats',
#   'the',
#   'why',
#   'whats',
#   'what',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'that.',
#   'that'],
#  'straight': ['up', 'up', 'up'],
#  'up': ['jealous.',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards.',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'dont',
#   'about',
#   'to',
#   'a',
#   'to',
#   'with',
#   'there',
#   'on',
#   'the',
#   'myself',
#   'from',
#   'your',
#   'soldier'],
#  'jealous.': ['im'],
#  'jealous,': ['first'],
#  'first': ['and',
#   'met',
#   'thing',
#   'dates,',
#   'and',
#   'passively',
#   'lady',
#   'webmd.',
#   'home',
#   'hbo'],
#  'foremost,': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them.',
#   'men',
#   'two',
#   'hpv.',
#   'wolverine,',
#   'grey,',
#   'tidying',
#   'success.',
#   'all',
#   'my',
#   'shit.',
#   'my',
#   'a',
#   'you',
#   'my',
#   'success.',
#   'losers.',
#   'losers.',
#   'skaters.',
#   'my',
#   'my',
#   'people',
#   'opinions,',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'los',
#   'all,',
#   'bleach,',
#   'your',
#   'this',
#   'asian',
#   'us',
#   'the',
#   'my',
#   'facebook,',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence.',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   'no!',
#   'the',
#   'control,',
#   'control',
#   'being',
#   'her,',
#   'saying,',
#   'saying:',
#   'income',
#   'one.',
#   'them.',
#   'shit.',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere.',
#   'their',
#   'her',
#   'those',
#   'longevity.',
#   'change.',
#   'mother',
#   'science',
#   'that',
#   'my',
#   'the',
#   'people',
#   'fuckin?',
#   'the',
#   'that,',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him',
#   'this',
#   'that',
#   'me.',
#   'women',
#   'women',
#   'shoes.',
#   'poppy',
#   'me',
#   'craigslist.',
#   'childbirth.',
#   'women',
#   'the',
#   'your',
#   'life,',
#   'how',
#   'my',
#   'the',
#   'survival,',
#   'another',
#   'those',
#   'body',
#   'losers.',
#   'my',
#   'white-collar'],
#  'their': ['metabolism.',
#   'feet',
#   'whole',
#   'house.',
#   'communist',
#   'shit,',
#   'doo',
#   'hallways',
#   'ipad',
#   'eyebrows,',
#   'prostate.',
#   'fame',
#   'existence.',
#   'big-ass',
#   'darth',
#   'arch-nemesis,',
#   'in',
#   'eyes',
#   'eyes.',
#   'eyes',
#   'head',
#   'eyelids.',
#   'face',
#   '',
#   'husbands'],
#  'metabolism.': ['because'],
#  'because': ['-year-old',
#   'its',
#   'my',
#   'my',
#   'you',
#   'what?',
#   'according',
#   'before',
#   'i',
#   'being',
#   'hes',
#   'hes',
#   'i',
#   'you',
#   'i',
#   'you',
#   'i',
#   'the',
#   'he',
#   'you',
#   'theyre',
#   'were',
#   'im',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'im',
#   'were',
#   'uh,',
#   'theyre',
#   'theyre',
#   'then',
#   'the',
#   'were',
#   'when',
#   'the',
#   'i',
#   'if',
#   'my–',
#   'he'],
#  'girls,': ['they'],
#  'they': ['could',
#   'take',
#   'got',
#   'put',
#   'go',
#   'just',
#   'dont',
#   'dont',
#   'have',
#   'dont',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'mean.',
#   'ruined',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'purposely',
#   'try',
#   'dont',
#   'dont',
#   'dont',
#   'want.',
#   'dont',
#   'can',
#   'can',
#   'want.\nyou',
#   'say',
#   'would',
#   'wax',
#   'do',
#   'get',
#   'like',
#   'just',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'dont',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'can',
#   'just',
#   'make',
#   'watch',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldnt',
#   'go',
#   'were',
#   'tried',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph.',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'and',
#   'crush',
#   'kill',
#   'like',
#   'black',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'lets',
#   'put',
#   'felt',
#   'wanted',
#   'sneak',
#   'give',
#   'give',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'choke',
#   'waiting',
#   'keep',
#   'try',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding.',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'i',
#   'scratch',
#   'vacuum,',
#   'come',
#   'give',
#   'got',
#   'and',
#   'twerk,',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like',
#   'gluten-free,',
#   'all',
#   'that',
#   'it,',
#   'snacks',
#   'a',
#   'bananas.'],
#  'like': ['shit,',
#   'to',
#   'fifty',
#   'the',
#   '$.',
#   'this',
#   'the',
#   'to',
#   'youre',
#   'voting',
#   'that',
#   'im',
#   'making',
#   'a',
#   'loofah',
#   'responsibility.',
#   'host',
#   'filipino',
#   'to',
#   'to',
#   'that.',
#   'free-range',
#   'a',
#   'we',
#   'youre',
#   'wiping',
#   'its',
#   'mrs.',
#   'youre',
#   'i',
#   'im',
#   'a',
#   'it,',
#   'that',
#   'hes',
#   'youre',
#   'to',
#   'a',
#   'a',
#   'the',
#   'skittles.',
#   'a',
#   'everything',
#   'a',
#   'they',
#   'losing',
#   'fingers.',
#   'whoppers',
#   'a',
#   'when'],
#  'shit,': ['and', 'too.'],
#  'then': ['they',
#   'after',
#   'also,',
#   'asian',
#   'if',
#   'afterwards,',
#   'it',
#   'i',
#   'you',
#   'you',
#   'your',
#   'if',
#   'i',
#   'i',
#   'resist',
#   'he',
#   'i',
#   'she',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'six-pack,': ['right?'],
#  'right?': ['they', 'they', 'thats', 'so,', 'you', 'im,'],
#  'got': ['that-that',
#   'so',
#   'married.',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married.',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'him',
#   'married,',
#   'pregnant,'],
#  'that-that': ['beautiful'],
#  'beautiful': ['inner'],
#  'inner': ['thigh', 'peace', 'evil,'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'i', 'the', 'the', 'i', 'they', 'im'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'now', 'to', 'when'],
#  'theres': ['that', 'this', 'multiple', 'nothing'],
#  'huge': ['gap', 'unspoken', 'sit-down', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is'],
#  'with': ['the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him.',
#   'him,',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes.',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me,',
#   'it,',
#   'you',
#   'intention,',
#   'me.',
#   'your',
#   'my',
#   'relationships,'],
#  'light': ['of', 'completely.'],
#  'potential': ['just'],
#  'radiating': ['through.\nand'],
#  'through.\nand': ['then,'],
#  'then,': ['when',
#   'all',
#   'it',
#   'you',
#   'on',
#   'at',
#   'at',
#   'a',
#   'when',
#   'because',
#   'i',
#   'you',
#   'i'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'bald',
#   'to',
#   'time,',
#   'through',
#   'to'],
#  'sleep,': ['they'],
#  'sleep.': ['right?'],
#  'insomnia': ['yet.'],
#  'yet.': ['they', 'they'],
#  'what': ['its',
#   'that',
#   'your',
#   'that',
#   'love',
#   'the',
#   'i',
#   'happens',
#   'youre',
#   'he',
#   'to',
#   'im',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'i',
#   'that',
#   'a'],
#  'ambien': ['or'],
#  'or': ['download',
#   'i',
#   'youre',
#   'you',
#   'for',
#   'something.',
#   'whatever.',
#   'something'],
#  'download': ['a'],
#  'meditation': ['oasis', 'retreats.'],
#  'oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind.',
#   '',
#   'wealth.',
#   'butt',
#   'mom.',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'co-workers',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame,',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers.',
#   'fingers',
#   'first',
#   ',',
#   ',',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg,',
#   'life.',
#   'doctors',
#   'body',
#   'nipples',
#   'email'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind.': ['they'],
#  'whole': ['lives', 'manipulation', 'new', 'foods', 'foods', 'thing.'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them.': ['they', 'theyre', 'nothing', 'once', 'they'],
#  'hpv': ['yet.', 'yet,', 'is', 'will'],
#  'sleep': ['in'],
#  'in': ['peace',
#   'men.',
#   'womens',
#   'the',
#   'books',
#   'the',
#   'handy',
#   'san',
#   'eight',
#   'a',
#   'san',
#   'broad',
#   'the',
#   'a',
#   'america',
#   'a',
#   'my',
#   'it.',
#   'the',
#   'and',
#   'men.',
#   '.',
#   'my',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time!',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed.',
#   'control',
#   'the',
#   'elementary',
#   'the',
#   'their–',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'your',
#   'such',
#   'the',
#   'atlanta.',
#   'their',
#   'front',
#   'my',
#   'labor,',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'debt.',
#   'his',
#   'which',
#   'an'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night.',
#   'home',
#   'this',
#   'the',
#   'the',
#   'golden',
#   'any',
#   'how,',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life,',
#   'first.',
#   'home,',
#   'any',
#   'my',
#   'fresh',
#   'some',
#   'my',
#   'work.',
#   'him.',
#   'his'],
#  'night.': ['everybody', 'and'],
#  'everybody': ['has', 'has', 'has', 'thought', 'doesnt', 'thought'],
#  'has': ['hpv,',
#   'it.',
#   'it.',
#   'hpv.',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'hpv,': ['ok?', 'because'],
#  'ok?': ['everybody',
#   'im',
#   'that',
#   'so,',
#   'you',
#   'a',
#   'i',
#   'you',
#   'so,',
#   'are',
#   'cause',
#   'we',
#   'i',
#   'old',
#   'do',
#   'when',
#   'when',
#   'and',
#   'and',
#   'they',
#   'are'],
#  'it.': ['its',
#   'if',
#   'you',
#   'its',
#   'you',
#   'second',
#   'so,',
#   'sheryl',
#   'i',
#   'when',
#   'im',
#   'now',
#   'thats'],
#  'ok.': ['come', 'and'],
#  'come': ['out', 'in', 'out,', 'up', 'out,', 'out', 'home,', 'with', 'out'],
#  'out': ['already.',
#   'of',
#   'there',
#   'of',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first.',
#   'that',
#   'of',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'about',
#   'yet',
#   'of',
#   'of'],
#  'already.': ['everybody'],
#  'if': ['you',
#   'the',
#   'it',
#   'he',
#   'a',
#   'you',
#   'you',
#   'i',
#   'youre',
#   'you',
#   'you',
#   'you',
#   'i',
#   'you',
#   'its',
#   'im',
#   'i',
#   'he',
#   'you',
#   'i',
#   'i'],
#  'it': ['yet,',
#   'might',
#   'was',
#   'was',
#   'all',
#   'was',
#   'when',
#   'cost',
#   'was',
#   'could',
#   'was',
#   'on',
#   'happened',
#   'happened',
#   'can',
#   'on',
#   'dont',
#   'was',
#   'came',
#   'on',
#   'on',
#   'as',
#   'so',
#   'for',
#   'a',
#   'basically',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up.',
#   'up,',
#   'interesting.',
#   'in',
#   'was',
#   'before,',
#   'tonight.',
#   'might',
#   'up.',
#   'was',
#   'in',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'made',
#   'gets',
#   'tells',
#   'was',
#   'was,',
#   'so',
#   'as',
#   'very',
#   'makes',
#   'takes',
#   'also',
#   'easier.',
#   'was',
#   'different?',
#   'up,',
#   'all',
#   'turns'],
#  'yet,': ['you', 'youre'],
#  'youre': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like,',
#   'too',
#   'like,',
#   'about',
#   'paranoid',
#   'like,',
#   'a',
#   'not',
#   'really',
#   'scared',
#   'married,',
#   'gonna',
#   'fucking',
#   'the',
#   'bossy,',
#   'supposed',
#   'a',
#   'eating',
#   'gonna',
#   'gonna',
#   'in',
#   ',',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser,', 'housewife.', 'different', 'baby.', 'baby,'],
#  'loser,': ['all'],
#  'all': ['right?',
#   'about.',
#   'of',
#   'your',
#   'came',
#   'required',
#   'because',
#   'this',
#   'right,',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day,',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'hes',
#   'squirmy',
#   'right?',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'of',
#   'the',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off.',
#   'right,',
#   'rights'],
#  'thats': ['what',
#   'gonna',
#   'right,',
#   'what',
#   'not',
#   'where',
#   'right,',
#   'like',
#   'how',
#   'how',
#   'not',
#   'right.',
#   'gonna',
#   'why',
#   'the',
#   'when',
#   'not',
#   'hilarious.',
#   'the',
#   'the',
#   'cool',
#   'not',
#   'so',
#   'shit',
#   'right.',
#   'so',
#   'like',
#   'my',
#   'why',
#   'a',
#   'enough',
#   'the',
#   'not'],
#  'says': ['about', 'to'],
#  'about': ['you.',
#   'the',
#   'him',
#   'a',
#   'vietnamese',
#   'it',
#   'supporting',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money.',
#   'anal.',
#   'is,',
#   'that',
#   'is,',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['dont', 'are', 'are', 'as'],
#  'undetectable': ['in'],
#  'men.': ['its', 'we'],
#  'really': ['fucked', 'work,', 'meant', 'scared', 'am!', 'take', 'am', 'hot,'],
#  'fucked': ['up.', 'a', 'up'],
#  'up.': ['hpv', 'yes.', 'a', 'you', 'shes', 'and'],
#  'ghost': ['that'],
#  'inside': ['mens', 'of'],
#  'mens': ['bodies'],
#  'bodies': ['and'],
#  'says,': ['boo!', 'please,'],
#  'boo!': ['in'],
#  'womens': ['bodies.', 'intuition.'],
#  'bodies.': ['my'],
#  'doctor': ['told', 'says', 'appointments.'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'me': ['that',
#   'that',
#   'to',
#   'something.',
#   'off?',
#   'feel',
#   'to',
#   'feel',
#   'the',
#   'tell',
#   'about',
#   'with',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on,',
#   'and',
#   'enough',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'see',
#   'of',
#   'company',
#   'when',
#   'when',
#   'anymore.',
#   'extremely',
#   'in',
#   'while',
#   'to',
#   'a',
#   'out.',
#   'out',
#   'to',
#   'money,',
#   'in',
#   'for'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'of', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'latina', 'sacks,', 'weeks'],
#  'strains': ['of'],
#  'hpv.': ['either', 'very'],
#  'either': ['i', 'im'],
#  'kind': ['thats', 'where', 'of', 'of', 'of', 'of'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'into': ['cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure.',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'cervical': ['cancer'],
#  'cancer': ['or'],
#  'body': ['will', 'is', 'hair', 'is', 'odor.', 'was', 'when', 'where,'],
#  'will': ['heal',
#   'also',
#   'also',
#   'you',
#   'always',
#   'be',
#   'have',
#   'commend',
#   'not'],
#  'heal': ['itself.', 'from'],
#  'itself.': ['very'],
#  'helpful,': ['this'],
#  'doctor,': ['right?'],
#  'so,': ['basically,',
#   'you',
#   'were',
#   'he',
#   'its',
#   'you',
#   'youre',
#   'i',
#   'when',
#   'in',
#   'motherfucker,',
#   'now,',
#   'i',
#   'i',
#   'my',
#   'then',
#   'then',
#   'i',
#   'you',
#   'as'],
#  'basically,': ['either'],
#  'die': ['or'],
#  'presence': ['of'],
#  'wolverine,': ['bitches.'],
#  'bitches.': ['well', 'i'],
#  'well': ['find', 'with', 'see'],
#  'find': ['out.', 'a', 'ways', 'a', 'it'],
#  'out.': ['um,', 'they', 'they', 'they'],
#  'um,': ['i', 'and'],
#  'also': ['tell', 'disappear.', 'got', 'last', 'dont', 'decided', 'takes'],
#  'kindle': ['is'],
#  'turning': ['into', 'into'],
#  'self-help': ['library.'],
#  'library.': ['im'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic,',
#   'recognize',
#   'doing',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again!',
#   'rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'ok.',
#   'fuckin.',
#   'because',
#   'doing',
#   'there.',
#   'gonna',
#   'like',
#   'the',
#   'be'],
#  'interested': ['in', 'in'],
#  'books': ['like'],
#  'fifty': ['shades'],
#  'shades': ['of'],
#  'grey,': ['ok?'],
#  'life-changing': ['magic'],
#  'magic': ['of'],
#  'tidying': ['up.'],
#  'yes.': ['yes,', 'yes.', 'yes.', 'i', 'because'],
#  'yes,': ['thats', 'i'],
#  'right,': ['how', 'ali,', 'we', 'because', 'ive'],
#  'how': ['to',
#   'can',
#   'can',
#   'proposals',
#   'did',
#   'rotten',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'theres,',
#   'it',
#   'did',
#   'did'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'and', 'all', 'and', 'together.'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success.': ['thats', 'i'],
#  'about.': ['how'],
#  'around?': ['im', 'help'],
#  'horrible': ['person,', 'toilet'],
#  'person,': ['im'],
#  'happy': ['with'],
#  'am,': ['how'],
#  'help': ['me,', 'me!\ni', 'her', 'you', 'as'],
#  'me,': ['tony',
#   'hes',
#   'this',
#   'but',
#   'i',
#   'because',
#   'oh,',
#   'im',
#   'out',
#   'with'],
#  'tony': ['robbins,'],
#  'robbins,': ['help'],
#  'me!\ni': ['have'],
#  'hoarding': ['problem,', 'goes', 'problem'],
#  'problem,': ['which'],
#  'which': ['im',
#   'is',
#   'a',
#   'means',
#   'would',
#   'is',
#   'means',
#   'their',
#   'is',
#   'is',
#   'hes',
#   'is',
#   'is',
#   'is',
#   'means',
#   'subsequently',
#   'he'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems.', 'homeless', 'day.', 'shitty'],
#  'problems.': ['im'],
#  'goes': ['away,', 'down'],
#  'away,': ['the'],
#  'disappear.': ['i', 'thats'],
#  'problem': ['because'],
#  'mom': ['is', 'got', 'is', 'is'],
#  'from': ['a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'pier',
#   'harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'holding',
#   'bacteria',
#   'harvard',
#   'the'],
#  'third': ['world', 'grade,', 'world'],
#  'world': ['country', '♪', 'with', 'country,'],
#  'country': ['and', 'and'],
#  'she': ['taught',
#   'refused',
#   'dont',
#   'was',
#   'wrote',
#   'knows',
#   'is',
#   'doesnt',
#   'was',
#   'said,'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called', 'go'],
#  'throw': ['away', 'up.', 'up'],
#  'away': ['anything,', 'from', 'at'],
#  'anything,': ['because'],
#  'dictators': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth.': ['so,'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'it.', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade,': ['cause'],
#  'might': ['come', 'need', 'mean'],
#  'handy': ['as'],
#  'as': ['a',
#   'a',
#   'an',
#   'women',
#   'much',
#   'they',
#   'a',
#   'many',
#   'possible',
#   'the',
#   'freaky',
#   'me.',
#   'a',
#   'old',
#   'her.',
#   'wet',
#   'it',
#   'pent-up,',
#   'angry',
#   'possible.',
#   'leverage',
#   'it',
#   'therapy.'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'in', 'makin'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['and', 'hole.', 'with', 'hole', 'cheeks', 'hole.'],
#  'running': ['away'],
#  'communists.\nthe': ['last'],
#  'last': ['time',
#   'forever.',
#   'boyfriend',
#   'time',
#   'year,',
#   'boyfriend',
#   'year,'],
#  'time': ['i', 'shitting', 'i', 'i', 'you'],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like,',
#   'like,',
#   'like,',
#   'that,',
#   'attending',
#   'like,',
#   'a',
#   'like,',
#   'living',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'cuban',
#   'like,',
#   'like,',
#   'like,',
#   'legit,',
#   'gonna',
#   'ready.',
#   'ripe.',
#   'rotten.',
#   'free?',
#   'like,',
#   'you.',
#   'like,',
#   'like,',
#   'like,',
#   'very',
#   'magical.',
#   'to',
#   'sliced',
#   'sliced',
#   'like,',
#   'like,',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   'in',
#   'ok,',
#   'clearly',
#   'that',
#   'easter',
#   'so',
#   'about',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   '',
#   'like,',
#   'like,',
#   '$,'],
#  'san': ['francisco,', 'francisco,'],
#  'francisco,': ['i', 'when'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'her': ['get',
#   'to',
#   'book',
#   'lululemon',
#   'butt.',
#   'nipples,',
#   'pussy',
#   'white',
#   'mexican',
#   'i'],
#  'rid': ['of'],
#  'shit.': ['dont', 'my', 'youre', 'its', 'they'],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know',
#   'fancy',
#   'yoga.',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'makes',
#   'it.',
#   'it',
#   'anything.',
#   'it!',
#   'anything.',
#   'you',
#   'write',
#   'that.',
#   'whatever',
#   'you',
#   'that.',
#   'all',
#   'anal',
#   'it',
#   'it.',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'you',
#   'in',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   'a',
#   'it?',
#   'you'],
#  'mom.': ['it', 'i', 'people'],
#  'worst': ['experience', 'thing'],
#  'experience': ['of', 'some'],
#  'life.': ['it', 'and'],
#  'emotional.': ['we'],
#  'were': ['screaming',
#   'all',
#   'in',
#   'hipsters,',
#   'getting',
#   'done,',
#   'both',
#   'like,',
#   'dumb',
#   'too',
#   'expected',
#   'so',
#   'like,',
#   'discouraging',
#   'like,',
#   'such',
#   'trying',
#   'like,',
#   '',
#   'alarmingly',
#   'suppositories,',
#   'trying',
#   'like,',
#   'not',
#   'hippies,',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['to', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['to', 'to'],
#  'let': ['go', 'two', 'me', 'it', 'me', 'their'],
#  'texas': ['instruments'],
#  'instruments': ['ti-'],
#  'ti-': ['manual.'],
#  'manual.': ['the', 'she'],
#  'calculator': ['is.', 'is.', 'that'],
#  'is.': ['those', 'it'],
#  'those': ['of', 'brains!', 'comments.', 'green', 'old', 'doctor', 'crazy'],
#  'under': [''],
#  'probably': ['dont', 'pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation.': ['we', 'you'],
# ...
#  'back': ['of', 'out', 'in', 'of', 'in', 'in'],
#  'volvo.': ['and'],
#  'after': ['we', 'they'],
#  'done,': ['he'],
#  'drop': ['me'],
#  'off?': ['i'],
#  'where?': ['he'],
#  'park.': ['and'],
#  'dropped': ['him'],
#  'off': ['at', 'and', 'the', 'the', 'of'],
#  'golden': ['gate'],
#  'gate': ['park'],
#  'watched': ['him'],
#  'run': ['into', 'over'],
#  'middle': ['with'],
#  'friends,': ['and', 'when', 'dead.', 'dead.', 'dead.'],
#  'no!': ['i', 'courtneys', 'no!', 'no!', 'no,', 'i', 'they', 'and', 'can'],
#  'dude!': ['again!'],
#  'again!': ['my', 'i'],
#  'husband': ['is',
#   'and',
#   'recently.',
#   'is',
#   'to',
#   'and',
#   'dies.',
#   'isnt',
#   'and',
#   'a',
#   'down',
#   'will',
#   'for',
#   'on,',
#   'was'],
#  'asian.': ['which', 'yeah!'],
#  'shocked': ['by,'],
#  'by,': ['because,'],
#  'usually,': ['asian-american'],
#  'asian-american': ['women', 'men', 'brothers'],
#  'women': ['who,',
#   'all',
#   'should',
#   'had',
#   'get',
#   'get',
#   'who',
#   'who',
#   'who',
#   'who',
#   'would',
#   'wont',
#   'tried'],
#  'who,': ['like,'],
#  'know,': ['wear',
#   'because',
#   'white',
#   'its',
#   'just',
#   'learning',
#   'i',
#   'squeeze',
#   'its–',
#   'and',
#   'a',
#   'is',
#   'i–',
#   'they',
#   'i–'],
#  'wear': ['these', 'that'],
#  'these': ['kinda',
#   'bitches.',
#   'chinese',
#   'women',
#   'boring,',
#   'other',
#   'hormone',
#   'ovulation'],
#  'kinda': ['glasses'],
#  'glasses': ['and', 'always'],
#  'opinions,': ['they'],
#  'date': ['white'],
#  'white': ['dudes.',
#   'dude',
#   'dude,',
#   'dudes,',
#   'dude.',
#   'dude',
#   'man!',
#   'people',
#   'people.',
#   'friends,',
#   'hippie'],
#  'dudes.': ['you'],
#  'any': ['hipster', 'moment,', 'real', 'sort', 'black', 'given'],
#  'hipster': ['neighborhood'],
#  'neighborhood': ['in'],
#  'major': ['city'],
#  'city': ['in'],
#  'america': ['and'],
#  'yoko': ['ono'],
#  'ono': ['factory.'],
#  'factory.': ['its'],
#  'too': ['much.', 'nice.', 'old', 'late', 'stupid', 'funky,'],
#  'much.': ['i', 'for'],
#  'whats': ['wrong', 'gonna', 'wrong', 'crackin?'],
#  'wrong': ['with', 'with'],
#  'it,': ['you', 'you', 'and', 'that', 'when', 'just'],
#  'being': ['with', 'the', 'courageous.', 'louis'],
#  'feel': ['very',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad,'],
#  'picturesque': ['when'],
#  'dude,': ['you', 'focus', 'and'],
#  'know.': ['you'],
#  'wes': ['anderson'],
#  'anderson': ['movie'],
#  'movie': ['or'],
#  'dudes,': ['they'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff', 'until'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling,': ['and'],
#  'disturbing': ['documentaries.'],
#  'documentaries.': ['they'],
#  'introduce': ['you'],
#  'very,': ['you', 'very'],
#  'hot': ['hookin'],
#  'hookin': ['up'],
#  'dude.': ['i', 'do', 'thats–'],
#  'mean,': ['nothing'],
#  'nothing': ['makes', 'they', 'for', 'back'],
#  'makes': ['me', 'me', 'sense,'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy.': ['oh,'],
#  'god.': ['i', 'its', 'thats', 'i'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement': ['you'],
#  'right': ['there,', 'now!', 'moment', 'turn–', 'there.', 'after'],
#  'through': ['the', 'southeast', 'and', 'a', 'it.', 'a'],
#  'money': ['hole', 'if'],
#  'hole': ['and', 'feels'],
#  'also,': ['hes'],
#  'vulnerable': ['down'],
#  'down': ['there.', 'there,', 'your', 'immediately', 'in', 'so', 'with'],
#  'there.': ['im,', 'i', 'but'],
#  'im,': ['like,', 'like,'],
#  'crush': ['your', 'those', 'while'],
#  'head': ['at', 'shredding', 'and', 'for'],
#  'moment,': ['white', 'you'],
#  'man!': ['i'],
#  'kill': ['you', 'me!'],
#  'now!': ['crush'],
#  'brains!': ['colonize'],
#  'colonize': ['the'],
#  'colonizer!': ['you'],
#  'know?\nbut': ['i'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'its',
#   'of',
#   'about',
#   'thats',
#   'so.',
#   'im'],
#  'marriage,': ['it', 'because'],
#  'nice': ['to'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race.', 'goddamn'],
#  'race.': ['the'],
#  'advantage': ['is'],
#  'racist': ['together.'],
#  'together.': ['you', 'my', 'and,'],
#  'say': ['whatever', 'to', 'be'],
#  'whatever': ['you', 'they', 'you', 'the'],
#  'like!': ['you'],
#  'explain': ['shit.'],
#  'half-filipino,': ['half-japanese.'],
#  'half-japanese.': ['im'],
#  'half-chinese': ['and', 'and'],
#  'half-vietnamese.': ['and', 'so,'],
#  'spend': [''],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time',
#   'first',
#   'buddha',
#   'careers.',
#   'job',
#   'day',
#   'society',
#   'first'],
#  'shitting': ['on'],
#  'korean': ['people.'],
#  'amazing.': ['its'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on,'],
#  'on,': ['you', 'you', 'like,'],
#  'know?\nmy': ['last'],
#  'boyfriend': ['was', 'because'],
#  'cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'i',
#   'crash.',
#   'simultaneously',
#   'explode.',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'mexican': ['people', 'friends,'],
#  'guys': ['arent', 'know', 'about', 'need', 'had.', 'can', 'doin'],
#  'arent': ['mexican?'],
#  'mexican?': ['asian-american'],
#  'underrated.': ['i'],
#  'why': ['people',
#   'you',
#   'else',
#   'you',
#   'are',
#   'are',
#   'dont',
#   'were',
#   'im',
#   'is',
#   'else'],
#  'sexiest.': ['asian', 'they'],
#  'asian': ['men',
#   'men,',
#   'and',
#   'people.',
#   'female',
#   'woman,',
#   'dont',
#   'ladies'],
#  'no': ['body', 'body', 'job.', 'unpredictable', 'kid', 'shame.'],
#  'hair': ['from'],
#  'neck': ['down.'],
#  'down.': ['its', 'i', 'i', 'people'],
#  'making': ['love'],
#  'dolphin.': ['oh,'],
#  'smooth,': ['just'],
#  'slip': ['and'],
#  'slide.': ['just'],
#  'black': ['fish,', 'dont', 'friends,', 'friends.'],
#  'fish,': ['tilikum,'],
#  'tilikum,': ['all'],
#  'bed': ['every'],
#  'every': ['night,',
#   'day.',
#   'single',
#   'day.',
#   'day.',
#   'day',
#   'day',
#   'time',
#   'single',
#   'time'],
#  'night,': ['you', 'everybody.'],
#  'know?': ['ooh-wee.',
#   'maybe',
#   'i',
#   'especially',
#   'my',
#   'like,',
#   'i',
#   'i',
#   'i',
#   'and,',
#   'your',
#   'and'],
#  'ooh-wee.': ['you'],
#  'mess': ['with'],
#  'jewish': ['dude', 'male'],
#  'afterwards.': ['its', 'i'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for,'],
#  'exfoliated': ['today.'],
#  'today.': ['this'],
#  'j-date,': ['more'],
#  'loofah': ['date.'],
#  'date.': ['thanks'],
#  'thanks': ['for'],
#  'rug': ['burn,'],
#  'burn,': ['avi.'],
#  'avi.': ['and'],
#  'men,': ['no'],
#  'odor.': ['none.'],
#  'none.': ['they'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility.': ['thats', 'and'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['from.\ni', 'out.', 'out', 'out,', 'to'],
#  'from.\ni': ['think'],
#  'unspoken': ['understanding,'],
#  'understanding,': ['uh,'],
#  'between': ['each', 'your'],
#  'each': ['other,', 'other.'],
#  'other,': ['because'],
#  'half-filipino': ['and'],
#  'half-japanese': ['and'],
#  'both': ['half-fancy', 'total,', 'are'],
#  'half-fancy': ['asian'],
#  'half-jungle': ['asian.'],
#  'yeah!': ['you', 'never', 'let'],
#  'difference.': ['the'],
#  'fancy': ['asians', 'things'],
#  'asians': ['are', 'host'],
#  'chinese,': ['the'],
#  'japanese.': ['they'],
#  'host': ['olympics.', 'diseases.'],
#  'olympics.': ['jungle'],
#  'jungle': ['asians'],
#  'diseases.': ['its'],
#  'different.': ['but', 'its'],
#  'east': ['coast,'],
#  'coast,': ['going'],
#  'private': ['school,', 'school,', 'school'],
#  'school,': ['playing', 'too.', 'and', 'the'],
#  'playing': ['lacrosse,', 'chess', 'dumb', 'candy'],
#  'lacrosse,': ['uh,'],
#  'learning': ['latin'],
#  'latin': ['and'],
#  'chess': ['and'],
#  'rugby.': ['he'],
#  'filipino': ['carlton,'],
#  'carlton,': ['ok?'],
#  'didnt': ['know', 'think', 'know', 'know'],
#  'anything': ['about'],
#  'vietnamese': ['people'],
#  'dates,': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['of', 'from', 'effect'],
#  'los': ['angeles'],
#  'angeles': ['called'],
#  'called': ['pho', 'lean', 'bossy.'],
#  'pho': ['show.'],
#  'show.': ['he', 'i', 'theres'],
#  'authentic': ['vietnamese.'],
#  'vietnamese.': ['i'],
#  'read': ['about'],
#  'yelp!': ['i'],
#  'authentic,': ['ok?'],
#  'tell,': ['first', 'but'],
#  'name,': ['cause'],
#  'number': ['in'],
#  'second': ['of', 'chance'],
#  'all,': ['you'],
#  'bathroom.': ['if'],
#  'legit,': ['the'],
#  'bathroom': ['would'],
#  'double': ['as', 'standard'],
#  'supply': ['closet.'],
#  'closet.': ['when'],
#  'pee,': ['i'],
#  'gallons': ['of'],
#  'bleach,': ['an'],
#  'atm': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner.': ['and'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'nice.': ['we'],
#  'leave': ['this', 'without', 'you,'],
#  'deaf': ['and'],
#  'emotionally': ['abused.'],
#  'abused.': ['i'],
#  'too.': ['him', 'we', 'but', 'they'],
#  'total,': ['like,'],
#  'school': ['asians.'],
#  'asians.': ['we'],
#  'big': ['hippies,', 'fantasy', 'impact'],
#  'hippies,': ['too.', 'id'],
#  'backpack': ['through'],
#  'southeast': ['asia.'],
#  'asia.': ['we'],
#  'yoga.': ['we'],
#  'ayahuasca': ['ceremonies.'],
#  'ceremonies.': ['we'],
#  'silent': ['meditation'],
#  'retreats.': ['thats'],
#  'pay': ['$', 'for'],
#  '$': ['to'],
#  'shut': ['up', 'the', 'up!', 'the'],
#  'weekend.': ['we'],
#  'gluten-free,': ['which'],
#  'means': ['we', 'i', 'the', 'youre'],
#  'bread': ['that', 'thats'],
#  'tastes': ['like', 'when'],
#  'free-range': ['chewbacca.'],
#  'chewbacca.': ['we'],
#  'lesbian': ['bread'],
#  'thousand': ['percent'],
#  'daily': ['fiber', 'basis.', 'basis'],
#  'fiber': ['and'],
#  'spoken': ['word'],
#  'word': ['poetry.', 'bossy', 'bossy,'],
#  'poetry.': ['when'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom.'],
#  'poem': ['about'],
#  'supporting': ['caitlyn'],
#  'caitlyn': ['jenner'],
#  'jenner': ['or'],
#  'whatever.': ['and'],
#  'funny,': ['right,'],
#  'asian,': ['too.'],
#  'sometimes,': ['all'],
#  'hippy-dippy': ['shit'],
#  'doing': ['an', 'anything.', 'jack', 'it.'],
#  'impression': ['of'],
#  'chinese': ['scrolls', 'ladies', 'ladies,'],
#  'scrolls': ['up'],
#  'wall': ['and', 'that'],
#  'neither': ['of'],
#  'us': ['know', 'to,'],
#  'mean.': ['were'],
#  'seems': ['to', 'to'],
#  'buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'pier': [''],
#  'imports.': ['that'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point,', 'of'],
#  'good': ['feng', 'in', 'night,'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house.': ['him', 'skin', 'hey,'],
#  'four': ['years', 'days'],
#  'years': ['and', 'old,', 'old,'],
#  'i–': ['i', 'i–', 'i,', 'i,'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose': ['because', 'to'],
#  'pressuring': ['him'],
#  'wacky': ['womens'],
#  'intuition.': ['thats'],
#  'proposals': ['really'],
#  'work,': ['ok?', 'we'],
#  'woman': ['has', 'is', 'wants', 'who'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'mans': ['head.', 'eye'],
#  'head.': ['first'],
#  'passively': ['and'],
#  'doesnt': ['get', 'see', 'have', 'have', 'believe'],
#  'message,': ['extremely'],
#  'extremely': ['aggressively.', 'itchy.'],
#  'aggressively.': ['you'],
#  'threaten': ['to'],
#  'without': ['ever', 'restraint.'],
#  'actually': ['leaving,'],
#  'leaving,': ['because'],
#  'old': ['and', 'as', 'chinese', 'chinese', 'asian'],
#  'late': ['to'],
#  'there': ['and', 'and', 'is', 'for', 'for', 'would'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again.': ['so,', 'and', 'its', 'but'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere.'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  'up!': ['fine,', 'dont'],
#  'fine,': ['will'],
#  'marry': ['me?', 'him'],
#  'me?': ['and', 'oh!'],
#  'afterwards,': ['the', 'and'],
#  'always,': ['like,'],
#  'god!': ['he', 'its', 'and'],
#  'proposed!': ['it'],
#  'nowhere.': ['and', 'and'],
#  'look,': ['he'],
#  'exact': ['ring'],
#  'ring': ['i'],
#  'wanted.': ['how', 'im'],
#  'maybe': ['he', 'youll', 'because'],
#  'pinterest': ['page', 'page'],
#  'page': ['or', 'hes'],
#  'something': ['that'],
#  'sent': ['to'],
#  'best': ['friend,', 'you'],
#  'friend,': ['that'],
#  'send': ['to'],
#  'day.': ['let', 'yeah.', 'which', 'housewives,', 'this'],
#  'pinterested': ['in'],
#  'engaged': ['on'],
#  'saturday.': ['i'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['tuesday'],
#  'tuesday': ['because'],
#  'tried': ['it', 'to', 'to'],
#  '.': ['i', 'girl,'],
#  'ready.': ['i'],
#  'ripe.': ['i'],
#  'rotten.': ['i'],
#  'banana': ['bread.'],
#  'bread.': ['thats'],
#  'rotten': ['i'],
#  'was.': ['people'],
#  'always': ['very', 'feel', 'catch', 'means', 'tell', 'wanted.'],
#  'surprised': ['at'],
#  'how,': ['off-stage,'],
#  'off-stage,': ['with'],
#  'completely': ['different'],
#  'different': ['person.', 'holes,', 'people.'],
#  'person.': ['you–'],
#  'you–': ['like,', 'that'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'him.': ['with', 'but'],
#  'soft,': ['and,'],
#  'nurturing': ['and'],
#  'domestic.': ['weve'],
#  'weve': ['been'],
#  'years,': ['and', 'ive'],
#  'ive': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day.', 'night.'],
#  'hed': ['become'],
#  'become': ['dependent', 'the', 'a', 'this', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'work': ['anymore.',
#   'anymore.',
#   'anymore.',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymore.'],
#  'dont.': ['i'],
#  'feed': ['him'],
#  'goodness': ['of'],
#  'heart.': ['i'],
#  'investment': ['in'],
#  'financial': ['future.'],
#  'reading': ['that'],
#  'book': ['by', 'that', 'is'],
#  'sheryl': ['sandberg,', 'sandberg,'],
#  'sandberg,': ['shes', 'that'],
#  'shes': ['the',
#   'not',
#   'retired.\ni',
#   'waiting.',
#   'timing',
#   'busy.',
#   'got',
#   'from'],
#  'c.o.o.': ['of'],
#  'facebook,': ['and'],
#  'wrote': ['that', 'lean'],
#  'riled': ['up'],
#  'careers.': ['talking'],
#  'talking': ['about', 'about?', 'about'],
#  'should': ['challenge', 'not'],
#  'challenge': ['ourselves'],
#  'ourselves': ['to'],
#  'sit': ['at'],
#  'table': ['and'],
#  'rise': ['to'],
#  'top.': ['and'],
#  'lean': ['in.', 'in,', 'in,'],
#  'in.': ['well,'],
#  'well,': ['i', 'asian'],
#  'lie': ['down.', 'the'],
#  'want': ['to', 'their–', 'to', 'my', 'noah', 'for', 'to', 'your'],
#  'feminism': ['is'],
#  'women.': ['our', 'we'],
#  'job': ['used', 'most'],
#  'used': ['to', 'to', 'it'],
#  'job.': ['we'],
#  'good.': ['we'],
#  'done': ['the', 'it'],
#  'smart': ['thing,'],
#  'thing,': ['which'],
#  'continue': ['playing'],
#  'dumb': ['for', 'women.'],
#  'century': ['and', 'more'],
#  'anything.': ['so,', 'bitch,', 'look'],
#  'guess': ['we', 'who'],
#  'stay': ['at'],
#  'snacks': ['and'],
#  'watch': ['ellen.', 'property', 'when', 'the'],
#  'ellen.': ['cause'],
#  'stupid': ['to'],
#  'real': ['responsibility.', 'boss.', 'miracle'],
#  'show': ['off', 'him', 'signs'],
#  'it!': ['we'],
#  'bitch,': ['shut'],
#  'them': ['the', 'up'],
#  'secret.': ['they'],
#  'ruined': ['it'],
#  'us,': ['and'],
#  'expected': ['to'],
#  'work.': ['when', 'i'],
#  'hear': ['the', 'my', 'that.'],
#  'phrase,': ['double-income'],
#  'double-income': ['household,'],
#  'household,': ['i'],
#  'upset': ['with'],
#  'comments.': ['and'],
#  'but,': ['ali,'],
#  'options': ['now.', 'when'],
#  'now.': ['oh,', 'but'],
#  'free?': ['unscheduled,'],
#  'unscheduled,': ['unsupervised,'],
#  'unsupervised,': ['and'],
#  'most': ['importantly,',
#   'strong-headed,',
#   'in',
#   'likely',
#   'of',
#   'of',
#   'women'],
#  'importantly,': ['sponsored?'],
#  'sponsored?': ['do'],
#  'shittier': ['food'],
#  'food': ['tastes'],
#  'earn': ['it?\na'],
#  'it?\na': ['lot'],
#  'walk': ['around'],
#  'around': ['together,', 'all', 'to', 'the', 'by'],
#  'together,': ['theyll'],
#  'theyll': ['get', 'be', 'get', 'be'],
#  'judgmental': ['about'],
#  'housewives': ['that', 'get', 'are'],
#  'street.': ['and'],
#  'look': ['at', 'at', 'in', 'on', 'like', 'me', 'forward', 'like', 'like'],
#  'housewife.': ['not'],
#  'housewife,': ['just', 'shes', 'financially,'],
#  'walking': ['around'],
#  'day,': ['getting', 'every'],
#  'massages': ['in'],
#  'lululemon': ['pants.'],
#  'pants.': ['im'],
#  'bitch': ['is', 'had'],
#  'genius.': ['shes'],
#  'retired.\ni': ['do'],
#  'write': ['for'],
#  'fresh': ['off', 'off'],
#  'boat': ['on'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
    # End it with a period
    sentence += '.'
    return(sentence)

# %%
print(generate_sentence(ali_dict))
# Out:
# Again! i dont! i grew up with my mom, my god, im gonna stick your.

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
data
# Out:
#                                                 transcript
# louis    intro\nfade the music out. lets roll. hold the...
# dave     this is dave. he tells dirty jokes for a livin...
# ricky    hello. hello! how you doing? great. thank you....
# bo           ©  scraps from the loft. all rights reserved.
# bill     [cheers and applause] all right, thank you! th...
# jim      [car horn honks] [audience cheering] [announce...
# john     armed with boyish charm and a sharp wit, the f...
# hasan        ©  scraps from the loft. all rights reserved.
# ali      ladies and gentlemen, please welcome to the st...
# anthony  thank you. thank you. thank you, san francisco...
# mike     wow. hey, thank you. thanks. thank you, guys. ...
# joe      [rock music playing] [audience cheering] [anno...

# %%
dave_text = data.transcript.loc["dave"]
dic = markov_chain(dave_text)
#print(i," generated text is")
print(generate_sentence(dic))
# Out:
# Gun for a lot of bubble gum and you were not be real, not complying?.

# %%
ricky_text = data.transcript.loc["ricky"]
dic = markov_chain(ricky_text)
#print(i," generated text is")
print(generate_sentence(dic))
# Out:
# Years. and even real news. dont punch anywhere. they will. bob was that reeled me.

# %%
import string 
import random

def generate_sentence_punc(chain, count=20):

    # Capitalize the first word
    word = random.choice(list(chain.keys()))
    sentence = word.capitalize()

    for i in range(count-1):
        word = random.choice(chain[word])
        sentence += ' ' + word
        
        import string
        puncs = string.punctuation 
        if word[-1] in puncs:
          return sentence

    # End it with a period
    sentence += random.choice(puncs)
    return(sentence)

# %%
for i in range(len(data)):
    print(data.index[i])
    text = data.transcript.iloc[i]
    star_dict = markov_chain(text)
    a=generate_sentence_punc(star_dict)
    print(a)
# Out:
# louis
# Does that.
# dave
# Cat could be like it.
# ricky
# Zoo, and gave her old is wrong with an x-ray,
# bo
# All rights reserved.
# bill
# Hugging your forehead.
# jim
# Actually know when a hand your bag yourself,
# john
# Biff, he would look upon your name,
# hasan
# The loft.
# ali
# Live. you know,
# anthony
# It, but he died.
# mike
# Class. i-ive given up to be like,
# joe
# Kick off into the people have that someone runs toward the church of guys will find them.
